# %% [markdown]
# ### Data Aanalyis for Diwali Sales Data (clickget)
#
# #### steps in Data Analysis
#
# > objective Draw Meaningfull insights and valueable information forecasting (future prediction) and decison making for business growth
#
# > Data collection - tabular format(rows,cols) - pandas
#
# > Data cleaning
#
# > EDA (Explotary Data Analysis)
#
# > visualization (charts) and key information
#
# > Conclusion: Report

# %%
# import libraries or modules
import numpy as np
import pandas as pd
# import dataset

# %%
# import dataset
df=pd.read_csv ('Diwali Sales Data.csv',encoding= 'unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Clothing & Apparel       2655
# Food                     2493
# Electronics & Gadgets    2087
# Footwear & Shoes         1064
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 353
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                      100
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: count, dtype: int64

# %%
df.duplicated().sum() # number of dulicates are 8
# Out:
# np.int64(8)

# %%
len(df)
# Out:
# 11251

# %%
df.drop_duplicates(inplace=True)

# %%
len(df) # 11251 - 8 = 11243
# Out:
# 11243

# %% [markdown]
# * Done with duplicate rows

# %%
df.nunique()
# Out:
# User_ID             3755
# Cust_name           1250
# Product_ID          2351
# Gender                 2
# Age Group              7
# Age                   81
# Marital_Status         2
# State                 16
# Zone                   5
# Occupation            15
# Product_Category      18
# Orders                 4
# Amount              6584
# Status                 0
# unnamed1               0
# dtype: int64

# %%
# checking the states where we sell our products
df['State'].value_counts()
# Out:
# State
# Uttar Pradesh       1944
# Maharashtra         1523
# Karnataka           1305
# Delhi               1107
# Madhya Pradesh       923
# Andhra Pradesh       812
# Himachal Pradesh     608
# Kerala               453
# Haryana              451
# Bihar                433
# Gujarat              428
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: count, dtype: int64

# %%
# checking null values 

df.isna ().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11243
# unnamed1            11243
# dtype: int64

# %%
# view null rows for amount cell
f1 = df['Amount'].isna()
df[f1]
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %%
# drop unwanted columns 
df.drop(columns=['Status','unnamed1'],inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
# drop rows where we have null values
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# * Done with unwanted cols and rows which has any null values

# %% [markdown]
# #### EDA

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11231 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11231 non-null  int64
#  1   Cust_name         11231 non-null  str
#  2   Product_ID        11231 non-null  str
#  3   Gender            11231 non-null  str
#  4   Age Group         11231 non-null  str
#  5   Age               11231 non-null  int64
#  6   Marital_Status    11231 non-null  int64
#  7   State             11231 non-null  str
#  8   Zone              11231 non-null  str
#  9   Occupation        11231 non-null  str
#  10  Product_Category  11231 non-null  str
#  11  Orders            11231 non-null  int64
#  12  Amount            11231 non-null  int16
# dtypes: int16(1), int64(4), str(8)
# memory usage: 1.1 MB

# %%
# typecasting of columns 
# Amount = float - int
df['Amount']=df['Amount'].astype('int16')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11231 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11231 non-null  int64
#  1   Cust_name         11231 non-null  str
#  2   Product_ID        11231 non-null  str
#  3   Gender            11231 non-null  str
#  4   Age Group         11231 non-null  str
#  5   Age               11231 non-null  int64
#  6   Marital_Status    11231 non-null  int64
#  7   State             11231 non-null  str
#  8   Zone              11231 non-null  str
#  9   Occupation        11231 non-null  str
#  10  Product_Category  11231 non-null  str
#  11  Orders            11231 non-null  int64
#  12  Amount            11231 non-null  int16
# dtypes: int16(1), int64(4), str(8)
# memory usage: 1.1 MB

# %%
# to view the statical information
df.describe()[['Age',	'Marital_Status',	'Orders',	'Amount']]
# Out:
#                 Age  Marital_Status        Orders        Amount
# count  11231.000000    11231.000000  11231.000000  11231.000000
# mean      35.411985        0.419998      2.489093   9454.084676
# std       12.756116        0.493580      1.114880   5221.728074
# min       12.000000        0.000000      1.000000    188.000000
# 25%       27.000000        0.000000      2.000000   5443.000000
# 50%       33.000000        0.000000      2.000000   8109.000000
# 75%       43.000000        1.000000      3.000000  12677.500000
# max       92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# find out number of male and female customer

# %%
  df['Gender'].value_counts()
# Out:
# Gender
# F    7828
# M    3403
# Name: count, dtype: int64

# %%
! pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ---------------------------------------- 80.3/80.3 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      -------------------------------------- 121.0/121.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB 7.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/9.3 MB 7.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/9.3 MB 8.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.4/9.3 MB 8.2 MB/s eta 0:00:01
#    ------- -------------------------------- 1.7/9.3 MB 7.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.0/9.3 MB 7.4 MB/s eta 0:00:01
# ...

# %%
! pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ------------------- -------------------- 143.4/294.9 kB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 2.6 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\klemp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    7828
# M    3403
# Name: count, dtype: int64

# %% [markdown]
# Gender

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Female are buying more then male

# %% [markdown]
# #### Who are spending more (Male/Female)?

# %%
 
df.groupby(['Gender'])['Amount'].count()
# Out:
# Gender
# F    7828
# M    3403
# Name: Amount, dtype: int64

# %%
 
sales_gen=df.groupby(['Gender'])['Amount'].sum().sort_values()

# %%
sales_gen
# Out:
# Gender
# M    31871146
# F    74307679
# Name: Amount, dtype: int64

# %%
type(sales_gen)
# Out:
# pandas.Series

# %%
sales_df=pd.DataFrame(sales_gen)

# %%
type(sales_df)
# Out:
# pandas.DataFrame

# %%
ax = sns.barplot(x = 'Gender', y = 'Amount' , data = sales_df)

for bar in ax.containers:
    ax.bar_label(bar)

# %%
> female are spending more then male

gender 
M    31871146
F    74307679

# %%
 74307679 - 31871146
# Out:
# 42436533

# %% [markdown]
# > female are spending more then male(with the difference of > female are spending more then m

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %%
Insights from age(col)
